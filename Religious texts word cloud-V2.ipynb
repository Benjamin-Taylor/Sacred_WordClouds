# %%
import numpy as np
from PIL import Image
from os import path
import matplotlib.pyplot as plt
import pylab
import random
from wordcloud import WordCloud, STOPWORDS

def grey_color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    return "hsl(0, 0%%, %d%%)" % random.randint(60, 100)

# %pylab inline
pylab.rcParams['figure.figsize'] = (18,10)

d = path.dirname("/media/system/100GB space/religioustexts/")

mask = np.array(Image.open(path.join(d, "BWbuddha.png"))) # reads BW buddha image

text = open("/media/system/100GB space/religioustexts/buddha.txt").read()

wc = WordCloud(max_words=2000, mask=mask, stopwords=STOPWORDS, margin=5,
               random_state=1).generate(text)

# store default colored image
default_colors = wc.to_array()
plt.title("The Gospel of Buddha as Buddha")
plt.imshow(wc.recolor(color_func=grey_color_func, random_state=3))
plt.axis("off")
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['pylab', 'text', 'random']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
import numpy as np
from PIL import Image
from os import path
import matplotlib.pyplot as plt
import random
import pylab
from wordcloud import WordCloud, STOPWORDS

def grey_color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    return "hsl(0, 0%%, %d%%)" % random.randint(60, 100)

# %pylab inline
pylab.rcParams['figure.figsize'] = (20,12)

d = path.dirname("/media/system/100GB space/religioustexts/")

mask = np.array(Image.open(path.join(d, "bwjesus3.jpg"))) # reads image

text = open("/media/system/100GB space/religioustexts/kingjamesbible.txt").read()


wc = WordCloud(max_words=2000, mask=mask, stopwords=STOPWORDS, margin=5,
               random_state=1).generate(text)

# store default colored image
default_colors = wc.to_array()
plt.title("The Bible as Jesus")
plt.imshow(wc.recolor(color_func=grey_color_func, random_state=3))
plt.axis("off")
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['random', 'pylab']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
import numpy as np
from PIL import Image
from os import path
import matplotlib.pyplot as plt
import random
import pylab
from wordcloud import WordCloud, STOPWORDS

def grey_color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    return "hsl(0, 0%%, %d%%)" % random.randint(60, 100)

# %pylab inline
pylab.rcParams['figure.figsize'] = (20,12)

d = path.dirname("/media/system/100GB space/religioustexts/")

mask = np.array(Image.open(path.join(d, "mormchurch3.jpg"))) # reads image

text = open("/media/system/100GB space/religioustexts/mormon.txt").read()


wc = WordCloud(max_words=2000, mask=mask, stopwords=STOPWORDS, margin=5,
               random_state=1).generate(text)

# store default colored image
default_colors = wc.to_array()
plt.title("The Book of Mormon as Latter Day Saints Church")
plt.imshow(wc.recolor(color_func=grey_color_func, random_state=3))
plt.axis("off")
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['text', 'random', 'pylab']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
import numpy as np
from PIL import Image
from os import path
import matplotlib.pyplot as plt
import random
import pylab
from wordcloud import WordCloud, STOPWORDS

def grey_color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    return "hsl(0, 0%%, %d%%)" % random.randint(60, 100)

# %pylab inline
pylab.rcParams['figure.figsize'] = (20,12)

d = path.dirname("/media/system/100GB space/religioustexts/")

mask = np.array(Image.open(path.join(d, "min2.png"))) # reads image

text = open("/media/system/100GB space/religioustexts/quran.txt").read()


wc = WordCloud(max_words=2000, mask=mask, stopwords=STOPWORDS, margin=5,
               random_state=1).generate(text)

# store default colored image
default_colors = wc.to_array()
plt.title("The Quran as Islamic Mosque")
plt.imshow(wc.recolor(color_func=grey_color_func, random_state=3))
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-a12e08b6de97> in <module>()
#       1 import numpy as np
# ----> 2 from PIL import Image
#       3 from os import path
#       4 import matplotlib.pyplot as plt
#       5 import random
#
# ImportError: No module named PIL
